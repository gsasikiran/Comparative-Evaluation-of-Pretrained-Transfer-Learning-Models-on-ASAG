# %%
# !git clone https://github.com/nshepperd/gpt-2
# Out:
# Cloning into 'gpt-2'...
# remote: Enumerating objects: 310, done.
# remote: Total 310 (delta 0), reused 0 (delta 0), pack-reused 310
# Receiving objects: 100% (310/310), 4.40 MiB | 3.75 MiB/s, done.
# Resolving deltas: 100% (167/167), done.

# %%
# !pip3 install fire

# %%
# !pip3 install regex

# %%
# !python3 /content/gpt-2/download_model.py 117M
# Out:
# Fetching checkpoint: 1.00kit [00:00, 767kit/s]
# Fetching encoder.json: 1.04Mit [00:00, 63.1Mit/s]
# Fetching hparams.json: 1.00kit [00:00, 836kit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:07, 68.7Mit/s]
# Fetching model.ckpt.index: 6.00kit [00:00, 4.45Mit/s]
# Fetching model.ckpt.meta: 472kit [00:00, 48.3Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 61.1Mit/s]

# %%
# !python3 /content/gpt-2/src/encoder.py /content/gpt-2/src/training_data.txt /content/gpt-2/src/train_encode.npz

# %%
# !python3 /content/gpt-2/train.py --dataset /content/gpt-2/src/train_encode.npz
# Out:
# Traceback (most recent call last):
#   File "/content/gpt-2/train.py", line 14, in <module>
#     import model, sample, encoder
# ModuleNotFoundError: No module named 'model'
