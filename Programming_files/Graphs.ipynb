# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
plt.rc('font', family='serif', weight='bold')
plt.rc('lines', lw=2)
plt.rc('xtick', labelsize='large')
plt.rc('ytick', labelsize='large')
plt.rc('axes', linewidth=2)

# %% [markdown]
# ## Pearson correlation

# %%
x = [1,2,3,4]
y_1 = [2,3,4,5]
y_2 = [1,4,3,5]
y_3 = [5,4,3,2]

# %%
def pearson_correlation(x,y):
        mean_x = sum(x) / len(x)
        mean_y = sum(y) / len(y)  
        cov = sum((a - mean_x) * (b - mean_y) for (a,b) in zip(x,y)) / len(x)
        
        std_x, std_y = np.std(x), np.std(y)

        p = cov/(std_x*std_y)

        return float(p)

# %%
pc_1 = pearson_correlation(x, y_1)
pc_2 = pearson_correlation(x, y_2)
pc_3 = pearson_correlation(x, y_3)

print(pc_1, pc_2, pc_3)
# Out:
# 0.9999999999999998 0.8315218406202998 -0.9999999999999998

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

sns.regplot(x, y_1)

ax.grid()
plt.xlabel('y', fontsize=14, weight='bold')
plt.ylabel('ŷ', fontsize=14, weight='bold')
plt.title("Pearson correlation = 1.000", fontsize=14, weight='bold')

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

sns.regplot(x, y_2, ci= None)

ax.grid(linestyle='--')
plt.xlabel('y', fontsize=14, weight='bold')
plt.ylabel('ŷ', fontsize=14, weight='bold')
plt.title("Pearson correlation = 0.832", fontsize=14, weight='bold')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

sns.regplot(x, y_3)

ax.grid(linestyle='--')
plt.xlabel('y', fontsize=14, weight='bold')
plt.ylabel('ŷ', fontsize=14, weight='bold')
plt.title("Pearson correlation = -1.000", fontsize=14, weight='bold')
plt.show()

# %% [markdown]
# ## Spearman coefficient

# %%
from scipy.stats import spearmanr

# %%
sc_x1 = np.linspace(-1,1,50)
sc_y1 = sc_x1**3

sc_x2 = np.random.random_sample(50)
sc_y2 = np.random.random_sample(50)

print(spearmanr(sc_x1, sc_y1))
print(spearmanr(sc_x2, sc_y2))
# Out:
# SpearmanrResult(correlation=0.9999999999999999, pvalue=0.0)
# SpearmanrResult(correlation=0.13248499399759903, pvalue=0.3590548333678273)

# %%
print(pearson_correlation(sc_x1, sc_y1))
print(pearson_correlation(sc_x2, sc_y2))
# Out:
# 0.9167597386426275
# 0.1237979441820152

# %%
plt.scatter(sc_x1,sc_y1)
plt.xlabel('y', fontsize=14, weight='bold')
plt.ylabel('ŷ', fontsize=14, weight='bold')
plt.grid(linestyle='--')
plt.title('Spearman correlation = 1.000 \n Pearson correlation = 0.917', fontsize=14,weight='bold')
plt.show()

# %%
plt.scatter(sc_x2,sc_y2)
plt.xlabel('y', fontsize=14, weight='bold')
plt.ylabel('ŷ', fontsize=14, weight='bold')
plt.grid(linestyle='--')
plt.title('Spearman correlation = 0.132 \n Pearson correlation = 0.124', fontsize=14,weight='bold')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
x = np.random.random_sample(50)
y = np.random.random_sample(50)

sns.regplot(x,y, ci=None, color='blue')
plt.grid(linestyle='--')
plt.xlabel('X', fontsize=14, weight='bold')
plt.ylabel('Y', fontsize=14, weight='bold')
plt.show()

# %% [markdown]
# ## RMSE, Pearson and Spearman with regression

# %%
rmse = np.array([[0.965, 0.965, 1.010],
                 [1.060, 1.060, 1.103],
                 [1.051, 1.052, 1.102],
                 [1.037, 1.038, 1.108]])
