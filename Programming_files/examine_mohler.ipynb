# %% [markdown]
# The cleaned dataset is taken from Tim Metzler.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/Colab Notebooks/RnD/dataset/datasets/mohler/cleaned'

# %% [markdown]
# ## Test data

# %%
data = pd.read_csv(path+'/answers.csv', error_bad_lines=False, delimiter='\t')

# %%
data['score_transformed'] = np.sqrt(data['score_avg'])

# %%
data.head()
# Out:
#    Unnamed: 0   id  ... score_avg  score_transformed
# 0           0  1.1  ...       3.5           1.870829
# 1           1  1.1  ...       5.0           2.236068
# 2           2  1.1  ...       4.0           2.000000
# 3           3  1.1  ...       5.0           2.236068
# 4           4  1.1  ...       3.0           1.732051
#
# [5 rows x 7 columns]

# %%
plt.rc('font', family='serif', weight='bold')
plt.rc('lines', lw=2)
plt.rc('xtick', labelsize='large')
plt.rc('ytick', labelsize='large')
plt.rc('axes', linewidth=2)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

count = data['score_avg'].value_counts(sort=False)
hist = data['score_avg'].hist(grid=False)

ax.set_xticks(np.arange(0,5.5,0.5))
ax.grid(linestyle='--')

plt.ylabel('count', fontsize=12, weight='bold')
plt.xlabel('score', fontsize=12, weight='bold')

plt.show()

# %%
print(data['score_avg'].mean())
print(data['score_avg'].median())
# Out:
# 4.165090189177299
# 4.5
